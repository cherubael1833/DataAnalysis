# %%
#importing required python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import struct
import glob
import matplotlib
import asn1tools
import json

# %%
asn1_files = glob.glob("/Users/eagmurray/Projects/DataAnalysis/Q40/flight_tests_12_May/ASN.1_files/*.asn")
schema = asn1tools.compile_files(asn1_files, "uper")

# %%
#loading the .jsonl log files
df_m10_decoded = pd.read_json("/Users/eagmurray/Projects/DataAnalysis/Q40/flight_tests_12_May/noAirRaid/Flight_2_noAR_30mAlt/decoded_log.jsonl",lines=True)

df_q40_raw = pd.read_json("/Users/eagmurray/Projects/DataAnalysis/Q40/flight_tests_12_May/noAirRaid/Flight_2_noAR_30mAlt/q40_nav_raw_log.jsonl",lines=True)
df_q40_decoded = pd.read_json("/Users/eagmurray/Projects/DataAnalysis/Q40/flight_tests_12_May/noAirRaid/Flight_2_noAR_30mAlt/q40_nav_decoded_log.jsonl",lines=True)

# %%
print(df_q40_raw["raw"][0])
payload = bytes.fromhex(df_q40_raw["raw"][0])
print(payload)
schema.decode("DataCoreNavSolution", payload)
# Out:
# 
# b'\x00\x00\x0bA\x9b2\x9c\xb2\xc3J~\x0ec\xa5\\uI@AV\xa0XO7>@\xc4\xc3f\x06\x93ZR@|6\x10$\x00\x00H@\tx H\x00\x003\xbc\xbd\x95\xdf\xb9\xcdf\x94<\x1c\'\x00\x00\x00\x00\x80\x00\x00\x00"A\x8dX\x04A\x9cz\x00\x00\x00\x00\x1b@\x7f\xda\xb6@\xff(\x00\x00\x00\x00\x00\x03W\x00\x00\x0c\x13\x00\x0c\t\n\x12\x00\x0f\x00\x80\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00D\x02\x00\x00`\x03\x00\x00\x00\x04\x00\x00\x00\x05\x00\x00\x00\x0f\x00\x00'
# {'validityTime': {'wordPadding': 0,
#   'timeReference': 'timeRefUTC',
#   'towSeconds': b'\x0bA\x9b2\x9c\xb2\xc3J'},
#  'dateTime': {'timeReference': 'reserved7',
#   'yearValid': True,
#   'monthValid': True,
#   'dayValid': True,
#   'wordPadding': 0,
#   'year': 230,
#   'month': 3,
#   'day': 20,
#   'hour': 21,
#   'minute': 28,
#   'second': 29,
#   'wordPadding1': 1},
#  'position': {'latitude': b'I@AV\xa0XO7',
#   'longitude': b'>@\xc4\xc3f\x06\x93Z',
#   'altitude': b'R@|6\x10$\x00\x00'},
#  'heightAboveGeoid': b'H@\tx H\x00\x00',
#  'velocity': {'east': b'3\xbc\xbd\x95',
#   'north': b'\xdf\xb9\xcdf',
#   'up': b"\x94<\x1c'"},
#  'magneticVariation': b'\x00\x00\x00\x00',
#  'wordPadding': 8,
#  'magneticVariationSource': 'magVarSourceNone',
#  'qFlag': False,
#  'encryptedServiceUsed': False,
#  'authenticatedServiceUsed': False,
#  'fixAided': False,
#  'wordPadding1': 0,
#  'datumID': 0,
#  'estimatedHorizPosErr': b'"A\x8dX',
#  'estimatedVertPosErr': b'\x04A\x9cz',
#  'estimatedTimeError': b'\x00\x00\x00\x00',
#  'estimatedHorizVelErr': b'\x1b@\x7f\xda',
#  'estimatedVertVelErr': b'\xb6@\xff(',
#  'estimatedTimeRateErr': b'\x00\x00\x00\x00',
#  'wordPadding2': 0,
#  'fixStatus': 'fixStatusNone',
#  'altitudeHeld': False,
#  'clockHeld': False,
#  'leverArmInUse': False,
#  'wordPadding3': 3,
#  'timeSinceLastGoodFix': 87,
#  'timeSinceLastNavSolModeChange': 0,
#  'satsInSolution': 0,
#  'satsInSolutionWithThreshCN0': 12,
#  'satsInSolutionTrackedInState5': 19,
#  'navSolutionMode': 'navSolModeAutoChoose',
#  'raimMode': 'raimModeNone',
#  'dilutionOfPrecision': {'horizontalDilutionOfPrecision': 12,
#   'verticalDilutionOfPrecision': 9,
#   'geometricDilutionOfPrecision': 10,
#   'timeDilutionOfPrecision': 18,
#   'positionDilutionOfPrecision': 0,
#   'wordPadding': 15},
#  'sensorsInUse': {'gnssSingleAntenna': False,
#   'gnssMultiAntenna': False,
#   'imu': False,
#   'magnetometer': False,
#   'baro': False,
#   'vehicleWheelSensorOdometer': False,
#   'accelerometer': False,
#   'singleAxisGyro': False,
#   'stableClock': True,
#   'ins': False,
#   'radAlt': False,
#   'trn': False,
#   'extNavData': False,
#   'velocityAiding': False,
#   'reservedBits': 0},
#  'ionoCorrectionInUse': 'ionoCorrectionNone',
#  'tropoCorrectionInUse': 'tropoCorrectionNone',
#  'correctionsInUse': 'correctionNone',
#  'wordPadding4': 2,
#  'leverArmValue': {'x': b'\x00\x00\x00\x00',
#   'y': b'\x00\x00\x00\x00',
#   'z': b'\x00\x00\x00\x00'},
#  'servicesInUse': {'wordPadding': 80, 'signalIDs': []}}

# %%
print(df_q40_raw["raw"][0])
payload = bytes.fromhex(df_q40_raw["raw"][0])
print(payload)

# Example ONLY — offsets must be confirmed
lat_offset = 16
lon_offset = 24

payload = bytearray(payload)

payload[lat_offset:lat_offset+8] = struct.pack("<d", 0.0)
payload[lon_offset:lon_offset+8] = struct.pack("<d", 0.0)

sanitised_hex = payload.hex()
print(sanitised_hex)
# Out:
# 
# b'\x00\x00\x0bA\x9b2\x9c\xb2\xc3J~\x0ec\xa5\\uI@AV\xa0XO7>@\xc4\xc3f\x06\x93ZR@|6\x10$\x00\x00H@\tx H\x00\x003\xbc\xbd\x95\xdf\xb9\xcdf\x94<\x1c\'\x00\x00\x00\x00\x80\x00\x00\x00"A\x8dX\x04A\x9cz\x00\x00\x00\x00\x1b@\x7f\xda\xb6@\xff(\x00\x00\x00\x00\x00\x03W\x00\x00\x0c\x13\x00\x0c\t\n\x12\x00\x0f\x00\x80\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00D\x02\x00\x00`\x03\x00\x00\x00\x04\x00\x00\x00\x05\x00\x00\x00\x0f\x00\x00'
# 

# %%
# Confirmed offsets
lat_offset = 16
lon_offset = 24

def sanitise_raw_hex(hex_string: str) -> str:
    payload = bytearray(bytes.fromhex(hex_string))

    payload[lat_offset:lat_offset+8] = struct.pack("<d", 0.0)
    payload[lon_offset:lon_offset+8] = struct.pack("<d", 0.0)

    return payload.hex()

# %%
# Make a copy so your original df stays untouched
df_q40_shared = df_q40_raw.copy()

# Apply sanitisation to every row
df_q40_shared["raw"] = df_q40_shared["raw"].apply(sanitise_raw_hex)

df_q40_shared.to_json("q40_raw_log_sanitised.jsonl", orient="records", lines=True)

# %%
payload = bytes.fromhex(df_q40_raw["raw"][250])
print(payload)
schema.decode("DataCoreNavSolution", payload)
# Out:
# b'\x00\x00\x0bAk:\xc6\xb2\x12\xce~\x0ec\xa5\x84yI@$VOr\x7f\xf3>@\xc5\xc4\xdc\xf26\xbab@\x88\xbf\x87m\x00\x80_@\xdd\x84\x0f\x1b\x00\x00\xb0\xc1!y\xe9@\xcb\x82\x9d>\xbc\xa7\x00\x00\x00\x00\x80\x00\x00\x00^A,\xc6.A\xcf\xf7\x00\x00\x00\x00K@B]\x8e?\x98(\x00\x00\x00\x00\x00\x03\xff\x00\x00\t\x13\x00\x10\r\x0b\x18\x00\x15\x00\x80\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00T\x02\x00\x00 \x03\x00\x00\x00\x04\x00\x00\x00\x05\x00\x00\x00\x0f\x00\x00'
# {'validityTime': {'wordPadding': 0,
#   'timeReference': 'timeRefUTC',
#   'towSeconds': b'\x0bAk:\xc6\xb2\x12\xce'},
#  'dateTime': {'timeReference': 'reserved7',
#   'yearValid': True,
#   'monthValid': True,
#   'dayValid': True,
#   'wordPadding': 0,
#   'year': 230,
#   'month': 3,
#   'day': 20,
#   'hour': 22,
#   'minute': 4,
#   'second': 30,
#   'wordPadding1': 1},
#  'position': {'latitude': b'I@$VOr\x7f\xf3',
#   'longitude': b'>@\xc5\xc4\xdc\xf26\xba',
#   'altitude': b'b@\x88\xbf\x87m\x00\x80'},
#  'heightAboveGeoid': b'_@\xdd\x84\x0f\x1b\x00\x00',
#  'velocity': {'east': b'\xb0\xc1!y',
#   'north': b'\xe9@\xcb\x82',
#   'up': b'\x9d>\xbc\xa7'},
#  'magneticVariation': b'\x00\x00\x00\x00',
#  'wordPadding': 8,
#  'magneticVariationSource': 'magVarSourceNone',
#  'qFlag': False,
#  'encryptedServiceUsed': False,
#  'authenticatedServiceUsed': False,
#  'fixAided': False,
#  'wordPadding1': 0,
#  'datumID': 0,
#  'estimatedHorizPosErr': b'^A,\xc6',
#  'estimatedVertPosErr': b'.A\xcf\xf7',
#  'estimatedTimeError': b'\x00\x00\x00\x00',
#  'estimatedHorizVelErr': b'K@B]',
#  'estimatedVertVelErr': b'\x8e?\x98(',
#  'estimatedTimeRateErr': b'\x00\x00\x00\x00',
#  'wordPadding2': 0,
#  'fixStatus': 'fixStatusNone',
#  'altitudeHeld': False,
#  'clockHeld': False,
#  'leverArmInUse': False,
#  'wordPadding3': 3,
#  'timeSinceLastGoodFix': 255,
#  'timeSinceLastNavSolModeChange': 0,
#  'satsInSolution': 0,
#  'satsInSolutionWithThreshCN0': 9,
#  'satsInSolutionTrackedInState5': 19,
#  'navSolutionMode': 'navSolModeAutoChoose',
#  'raimMode': 'raimModeNone',
#  'dilutionOfPrecision': {'horizontalDilutionOfPrecision': 16,
#   'verticalDilutionOfPrecision': 13,
#   'geometricDilutionOfPrecision': 11,
#   'timeDilutionOfPrecision': 24,
#   'positionDilutionOfPrecision': 0,
#   'wordPadding': 21},
#  'sensorsInUse': {'gnssSingleAntenna': False,
#   'gnssMultiAntenna': False,
#   'imu': False,
#   'magnetometer': False,
#   'baro': False,
#   'vehicleWheelSensorOdometer': False,
#   'accelerometer': False,
#   'singleAxisGyro': False,
#   'stableClock': True,
#   'ins': False,
#   'radAlt': False,
#   'trn': False,
#   'extNavData': False,
#   'velocityAiding': False,
#   'reservedBits': 0},
#  'ionoCorrectionInUse': 'ionoCorrectionNone',
#  'tropoCorrectionInUse': 'tropoCorrectionNone',
#  'correctionsInUse': 'correctionNone',
#  'wordPadding4': 2,
#  'leverArmValue': {'x': b'\x00\x00\x00\x00',
#   'y': b'\x00\x00\x00\x00',
#   'z': b'\x00\x00\x00\x00'},
#  'servicesInUse': {'wordPadding': 80, 'signalIDs': []}}

# %%
print(df_m10_decoded["lon"][0])
print(df_q40_decoded["lon"][0])
# Out:
# 30.76294
# 30.76470985411522

# %%
# Copy to preserve originals
df_q40_out = df_q40_decoded.copy()
df_m10_out = df_m10_decoded.copy()

# Apply shift
df_q40_out["lat"] = df_q40_out["lat"] - 30
df_q40_out["lon"] = df_q40_out["lon"] - 30

df_m10_out["lat"] = df_m10_out["lat"] - 30
df_m10_out["lon"] = df_m10_out["lon"] - 30

# %%
df_q40_out.to_json("q40_decoded_sanitised.jsonl", orient="records", lines=True)
df_m10_out.to_json("m10_decoded_sanitised.jsonl", orient="records", lines=True)

print("Done — shifted logs written.")
# Out:
# Done — shifted logs written.
