# %%
#importing required python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import struct
import glob
import matplotlib
import asn1tools
import json

# %%
asn1_files = glob.glob("ASN.1_files/*.asn")
schema = asn1tools.compile_files(asn1_files, "uper")

# %%
#loading the .jsonl log files
df_m10_decoded = pd.read_json("M10_1718March/decoded_log.jsonl",lines=True)
df_m10_raw = pd.read_json("M10_1718March/raw_log.jsonl",lines=True)

df_q40_raw = pd.read_json("Q40_1718March/raw_log.jsonl",lines=True)
df_q40_decoded = pd.read_json("Q40_1718March/decoded_log.jsonl",lines=True)

# %%
print(df_q40_raw["raw"][0])
payload = bytes.fromhex(df_q40_raw["raw"][0])
print(payload)
schema.decode("DataCoreNavSolution", payload)
# Out:
# 
# b"\x00\x00A\x0b\xf8=\xa3W\x0fw\x0e~\xa3\x8b\xe6\xc0@I8'\xe7e\xe8F@>\x84\xa5\xa1\xe8\x98I@TS,\x12\r\x00\x00@L5\x9a\xa4\x1a\x00\x00\xbf0%\x7f\xbeD\xc9\x02>\xd4\xa8\xfd\x00\x00\x00\x00\x00\x00\x00\x00B()\x14A\xf4\x87\x7f\x00\x00\x00\x00?\x8ae\x02?%Rt\x00\x00\x00\x00\x03\x00\x01p\x07\x00\x00\x13A-hDO\x00\x80\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x02T\x00\x00\x03 \x00\x00\x04\x00\x00\x00\x05\x00\x00\x00\x0f\x00\x00\x00"
# {'validityTime': {'wordPadding': 0,
#   'timeReference': 'timeRefUTC',
#   'towSeconds': b'A\x0b\xf8=\xa3W\x0fw'},
#  'dateTime': {'timeReference': 'timeRefUTC',
#   'yearValid': True,
#   'monthValid': True,
#   'dayValid': True,
#   'wordPadding': 0,
#   'year': 2026,
#   'month': 3,
#   'day': 17,
#   'hour': 15,
#   'minute': 38,
#   'second': 48,
#   'wordPadding1': 0},
#  'position': {'latitude': b"@I8'\xe7e\xe8F",
#   'longitude': b'@>\x84\xa5\xa1\xe8\x98I',
#   'altitude': b'@TS,\x12\r\x00\x00'},
#  'heightAboveGeoid': b'@L5\x9a\xa4\x1a\x00\x00',
#  'velocity': {'east': b'\xbf0%\x7f',
#   'north': b'\xbeD\xc9\x02',
#   'up': b'>\xd4\xa8\xfd'},
#  'magneticVariation': b'\x00\x00\x00\x00',
#  'wordPadding': 0,
#  'magneticVariationSource': 'magVarSourceNone',
#  'qFlag': False,
#  'encryptedServiceUsed': False,
#  'authenticatedServiceUsed': False,
#  'fixAided': False,
#  'wordPadding1': 0,
#  'datumID': 0,
#  'estimatedHorizPosErr': b'B()\x14',
#  'estimatedVertPosErr': b'A\xf4\x87\x7f',
#  'estimatedTimeError': b'\x00\x00\x00\x00',
#  'estimatedHorizVelErr': b'?\x8ae\x02',
#  'estimatedVertVelErr': b'?%Rt',
#  'estimatedTimeRateErr': b'\x00\x00\x00\x00',
#  'wordPadding2': 0,
#  'fixStatus': 'fixStatusThreeDimensional',
#  'altitudeHeld': False,
#  'clockHeld': False,
#  'leverArmInUse': False,
#  'wordPadding3': 0,
#  'timeSinceLastGoodFix': 1,
#  'timeSinceLastNavSolModeChange': 112,
#  'satsInSolution': 7,
#  'satsInSolutionWithThreshCN0': 0,
#  'satsInSolutionTrackedInState5': 0,
#  'navSolutionMode': 'navSolModeGNSSUnfiltered',
#  'raimMode': 'raimModeFaultDetectionAndExclusion',
#  'dilutionOfPrecision': {'horizontalDilutionOfPrecision': 65,
#   'verticalDilutionOfPrecision': 45,
#   'geometricDilutionOfPrecision': 104,
#   'timeDilutionOfPrecision': 68,
#   'positionDilutionOfPrecision': 79,
#   'wordPadding': 0},
#  'sensorsInUse': {'gnssSingleAntenna': True,
#   'gnssMultiAntenna': False,
#   'imu': False,
#   'magnetometer': False,
#   'baro': False,
#   'vehicleWheelSensorOdometer': False,
#   'accelerometer': False,
#   'singleAxisGyro': False,
#   'stableClock': False,
#   'ins': False,
#   'radAlt': False,
#   'trn': False,
#   'extNavData': False,
#   'velocityAiding': False,
#   'reservedBits': 0},
#  'ionoCorrectionInUse': 'ionoCorrectionNone',
#  'tropoCorrectionInUse': 'tropoCorrectionModel',
#  'correctionsInUse': 'correctionNone',
#  'wordPadding4': 0,
#  'leverArmValue': {'x': b'\x00\x00\x00\x00',
#   'y': b'\x00\x00\x00\x00',
#   'z': b'\x00\x00\x00\x00'},
#  'servicesInUse': {'wordPadding': 0,
#   'signalIDs': [{'wordPadding': 0,
#     'multiSignalID': ('gps',
#      {'gpsSigAutoChoose': False,
#       'gpsSigL1CA': True,
#       'gpsSigL1C': False,
#       'gpsSigL2CM': True,
#       'gpsSigL2CL': False,
#       'gpsSigL5': True,
#       'gpsSigL1PY': False,
#       'gpsSigL2PY': False,
#       'gpsSigL1MCode': False,
#       'gpsSigL2MCode': False,
#       'reservedBits': 0})},
#    {'wordPadding': 0,
#     'multiSignalID': ('gal',
#      {'galSigAutoChoose': False,
#       'galSigE1bc': False,
#       'galSigE5a': True,
#       'galSigE5b': False,
#       'galSigE6bc': False,
#       'galSigE1a': False,
#       'galSigE6a': False,
#       'reservedBits': 0})},
#    {'wordPadding': 0,
#     'multiSignalID': ('glo',
#      {'gloSigAutoChoose': False,
#       'gloSigL1OF': False,
#       'gloSigL1SFEncrypted': False,
#       'gloSigL2OF': False,
#       'gloSigL2SFEncrypted': False,
#       'gloSigL3OC': False,
#       'gloSigL1OC': False,
#       'gloSigL1SCEncrypted': False,
#       'gloSigL2OC': False,
#       'gloSigL2SCEncrypted': False,
#       'reservedBits': 0})},
#    {'wordPadding': 0,
#     'multiSignalID': ('bds',
#      {'bdsSigAutoChoose': False,
#       'bdsSigL1OS': False,
#       'bdsSigL1Encrypted': False,
#       'bdsSigL2OS': False,
#       'bdsSigL2Encrypted': False,
#       'reservedBits': 0})},
#    {'wordPadding': 0,
#     'multiSignalID': ('sbas',
#      {'sbasSigAutoChoose': False,
#       'sbasSigL1WAAS': False,
#       'sbasSigL5WAAS': False,
#       'sbasSigL1EGNOS': False,
#       'sbasSigSDCM': False,
#       'sbasSigSNAS': False,
#       'sbasSigGAGAN': False,
#       'sbasSigMSAS': False,
#       'reservedBits': 0})}]}}

# %%
print(df_q40_raw["raw"][0])
payload = bytes.fromhex(df_q40_raw["raw"][0])
print(payload)

# Example ONLY — offsets must be confirmed
lat_offset = 16
lon_offset = 24

payload = bytearray(payload)

payload[lat_offset:lat_offset+8] = struct.pack("<d", 0.0)
payload[lon_offset:lon_offset+8] = struct.pack("<d", 0.0)

sanitised_hex = payload.hex()
print(sanitised_hex)
# Out:
# 
# b"\x00\x00A\x0b\xf8=\xa3W\x0fw\x0e~\xa3\x8b\xe6\xc0@I8'\xe7e\xe8F@>\x84\xa5\xa1\xe8\x98I@TS,\x12\r\x00\x00@L5\x9a\xa4\x1a\x00\x00\xbf0%\x7f\xbeD\xc9\x02>\xd4\xa8\xfd\x00\x00\x00\x00\x00\x00\x00\x00B()\x14A\xf4\x87\x7f\x00\x00\x00\x00?\x8ae\x02?%Rt\x00\x00\x00\x00\x03\x00\x01p\x07\x00\x00\x13A-hDO\x00\x80\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x02T\x00\x00\x03 \x00\x00\x04\x00\x00\x00\x05\x00\x00\x00\x0f\x00\x00\x00"
# 

# %%
# Confirmed offsets
lat_offset = 16
lon_offset = 24

def sanitise_raw_hex(hex_string: str) -> str:
    payload = bytearray(bytes.fromhex(hex_string))

    payload[lat_offset:lat_offset+8] = struct.pack("<d", 0.0)
    payload[lon_offset:lon_offset+8] = struct.pack("<d", 0.0)

    return payload.hex()

# %%
# Make a copy so your original df stays untouched
df_q40_shared = df_q40_raw.copy()

# Apply sanitisation to every row
df_q40_shared["raw"] = df_q40_shared["raw"].apply(sanitise_raw_hex)

df_q40_shared.to_json("raw_log_sanitised.jsonl", orient="records", lines=True)

# %%
payload = bytes.fromhex(df_q40_raw["raw"][1000])
print(payload)
schema.decode("DataCoreNavSolution", payload)
# Out:
# b'\x00\x00A\x0c\x17}\xa3\x99\xe5\x91\x0e~\xa3\x8b\xf7p@I8\x1a@\x8c\xb4\xc9@>\x84+\xde\x04\xd8\xc5@h\x063v\xf4\x80\x00@d\xe9\xe1\x96\xf4\x80\x00:\xb3!\x0c\xba\xf5\rS<>\x91\xba\x00\x00\x00\x00\x00\x80\x00\x00@\xd2*K@\xe4)[\x00\x00\x00\x00=W\xb3\xc7=\x8a\xeb\xa7\x00\x00\x00\x00\x03\x00\x00\xff\x08\x00\x00\x13\x0c\x0f\x16\x0b\x13\x00\x80\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x02D\x00\x00\x03 \x00\x00\x04\x00\x00\x00\x05\x00\x00\x00\x0f\x00\x00\x00'
# {'validityTime': {'wordPadding': 0,
#   'timeReference': 'timeRefUTC',
#   'towSeconds': b'A\x0c\x17}\xa3\x99\xe5\x91'},
#  'dateTime': {'timeReference': 'timeRefUTC',
#   'yearValid': True,
#   'monthValid': True,
#   'dayValid': True,
#   'wordPadding': 0,
#   'year': 2026,
#   'month': 3,
#   'day': 17,
#   'hour': 15,
#   'minute': 55,
#   'second': 28,
#   'wordPadding1': 0},
#  'position': {'latitude': b'@I8\x1a@\x8c\xb4\xc9',
#   'longitude': b'@>\x84+\xde\x04\xd8\xc5',
#   'altitude': b'@h\x063v\xf4\x80\x00'},
#  'heightAboveGeoid': b'@d\xe9\xe1\x96\xf4\x80\x00',
#  'velocity': {'east': b':\xb3!\x0c',
#   'north': b'\xba\xf5\rS',
#   'up': b'<>\x91\xba'},
#  'magneticVariation': b'\x00\x00\x00\x00',
#  'wordPadding': 0,
#  'magneticVariationSource': 'magVarSourceNone',
#  'qFlag': True,
#  'encryptedServiceUsed': False,
#  'authenticatedServiceUsed': False,
#  'fixAided': False,
#  'wordPadding1': 0,
#  'datumID': 0,
#  'estimatedHorizPosErr': b'@\xd2*K',
#  'estimatedVertPosErr': b'@\xe4)[',
#  'estimatedTimeError': b'\x00\x00\x00\x00',
#  'estimatedHorizVelErr': b'=W\xb3\xc7',
#  'estimatedVertVelErr': b'=\x8a\xeb\xa7',
#  'estimatedTimeRateErr': b'\x00\x00\x00\x00',
#  'wordPadding2': 0,
#  'fixStatus': 'fixStatusThreeDimensional',
#  'altitudeHeld': False,
#  'clockHeld': False,
#  'leverArmInUse': False,
#  'wordPadding3': 0,
#  'timeSinceLastGoodFix': 0,
#  'timeSinceLastNavSolModeChange': 255,
#  'satsInSolution': 8,
#  'satsInSolutionWithThreshCN0': 0,
#  'satsInSolutionTrackedInState5': 0,
#  'navSolutionMode': 'navSolModeGNSSUnfiltered',
#  'raimMode': 'raimModeFaultDetectionAndExclusion',
#  'dilutionOfPrecision': {'horizontalDilutionOfPrecision': 12,
#   'verticalDilutionOfPrecision': 15,
#   'geometricDilutionOfPrecision': 22,
#   'timeDilutionOfPrecision': 11,
#   'positionDilutionOfPrecision': 19,
#   'wordPadding': 0},
#  'sensorsInUse': {'gnssSingleAntenna': True,
#   'gnssMultiAntenna': False,
#   'imu': False,
#   'magnetometer': False,
#   'baro': False,
#   'vehicleWheelSensorOdometer': False,
#   'accelerometer': False,
#   'singleAxisGyro': False,
#   'stableClock': False,
#   'ins': False,
#   'radAlt': False,
#   'trn': False,
#   'extNavData': False,
#   'velocityAiding': False,
#   'reservedBits': 0},
#  'ionoCorrectionInUse': 'ionoCorrectionNone',
#  'tropoCorrectionInUse': 'tropoCorrectionModel',
#  'correctionsInUse': 'correctionNone',
#  'wordPadding4': 0,
#  'leverArmValue': {'x': b'\x00\x00\x00\x00',
#   'y': b'\x00\x00\x00\x00',
#   'z': b'\x00\x00\x00\x00'},
#  'servicesInUse': {'wordPadding': 0,
#   'signalIDs': [{'wordPadding': 0,
#     'multiSignalID': ('gps',
#      {'gpsSigAutoChoose': False,
#       'gpsSigL1CA': True,
#       'gpsSigL1C': False,
#       'gpsSigL2CM': False,
#       'gpsSigL2CL': False,
#       'gpsSigL5': True,
#       'gpsSigL1PY': False,
#       'gpsSigL2PY': False,
#       'gpsSigL1MCode': False,
#       'gpsSigL2MCode': False,
#       'reservedBits': 0})},
#    {'wordPadding': 0,
#     'multiSignalID': ('gal',
#      {'galSigAutoChoose': False,
#       'galSigE1bc': False,
#       'galSigE5a': True,
#       'galSigE5b': False,
#       'galSigE6bc': False,
#       'galSigE1a': False,
#       'galSigE6a': False,
#       'reservedBits': 0})},
#    {'wordPadding': 0,
#     'multiSignalID': ('glo',
#      {'gloSigAutoChoose': False,
#       'gloSigL1OF': False,
#       'gloSigL1SFEncrypted': False,
#       'gloSigL2OF': False,
#       'gloSigL2SFEncrypted': False,
#       'gloSigL3OC': False,
#       'gloSigL1OC': False,
#       'gloSigL1SCEncrypted': False,
#       'gloSigL2OC': False,
#       'gloSigL2SCEncrypted': False,
#       'reservedBits': 0})},
#    {'wordPadding': 0,
#     'multiSignalID': ('bds',
#      {'bdsSigAutoChoose': False,
#       'bdsSigL1OS': False,
#       'bdsSigL1Encrypted': False,
#       'bdsSigL2OS': False,
#       'bdsSigL2Encrypted': False,
#       'reservedBits': 0})},
#    {'wordPadding': 0,
#     'multiSignalID': ('sbas',
#      {'sbasSigAutoChoose': False,
#       'sbasSigL1WAAS': False,
#       'sbasSigL5WAAS': False,
#       'sbasSigL1EGNOS': False,
#       'sbasSigSDCM': False,
#       'sbasSigSNAS': False,
#       'sbasSigGAGAN': False,
#       'sbasSigMSAS': False,
#       'reservedBits': 0})}]}}

# %%
print(df_m10_decoded["lon"][0])
print(df_q40_decoded["lon"][0])
# Out:
# 30.5169292
# 30.518152350698333

# %%
# Copy to preserve originals
df_q40_out = df_q40_decoded.copy()
df_m10_out = df_m10_decoded.copy()

# Apply shift
df_q40_out["lat"] = df_q40_out["lat"] - 30
df_q40_out["lon"] = df_q40_out["lon"] - 30

df_m10_out["lat"] = df_m10_out["lat"] - 30
df_m10_out["lon"] = df_m10_out["lon"] - 30

# %%
df_q40_out.to_json("q40_decoded_sanitised.jsonl", orient="records", lines=True)
df_m10_out.to_json("m10_decoded_sanitised.jsonl", orient="records", lines=True)

print("Done — shifted logs written.")
# Out:
# Done — shifted logs written.
