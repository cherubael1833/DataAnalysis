# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
x = np.arange(0,6*np.pi,0.1)
freq = 1575.42*10**6 #L1 centre frequency
wave_og = 1*np.sin(x*freq)
wave_jam = 10*np.sin(x*freq)
print(freq)
# Out:
# 1575420000.0

# %%
fig,ax = plt.subplots(figsize = (10,6),dpi=300)


def pi_formatter(x, pos):
    return f"{x/np.pi:g}π"

matplotlib.rcParams['font.family'] = 'Arial'
matplotlib.rcParams.update({'font.size': 8})
ax.plot(x,wave_og,label="L1 GNSS Signal",color="#001F3D")
ax.plot(x,wave_jam,label="Damba Jamming Signal",color="#39CCCC")
ax.legend()
ax.set_title("GPS Jamming Example: 1575.42MHz L1 Signal")
ax.set_xlabel("Radians")
ax.set_ylabel("Amplitude")
ax.xaxis.set_major_formatter(tck.FuncFormatter(pi_formatter))
ax.xaxis.set_major_locator(tck.MultipleLocator(base=np.pi))
plt.savefig("jammed_plot.jpg", dpi=300, bbox_inches='tight')
